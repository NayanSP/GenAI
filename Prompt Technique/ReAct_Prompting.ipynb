# %%
import openai
import os
from langchain_openai import ChatOpenAI
from langchain_core.agents import load_tools
from langchain_core.agents import initialize_agent
from dotenv import load_dotenv
load_dotenv()
 
# load API keys; you will need to obtain these if you haven't yet
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 4
#       1 import openai
#       2 import os
#       3 from langchain_openai import ChatOpenAI
# ----> 4 from langchain_core.agents import load_tools
#       5 from langchain_core.agents import initialize_agent
#       6 from dotenv import load_dotenv
#       7 load_dotenv()
#
# ImportError: cannot import name 'load_tools' from 'langchain_core.agents' (c:\Users\Nayan\Downloads\GenAIProjects\.venv\Lib\site-packages\langchain_core\agents.py)

# %%
llm = ChatOpenAI(temperature=0)
tools = load_tools(["google-serper", "llm-math"], llm=llm)
agent = initialize_agent(tools, llm, agent="zero-shot-react-description", verbose=True)

# %%
agent.run("Who is Olivia Wilde's boyfriend? What is his current age raised to the 0.23 power?")
