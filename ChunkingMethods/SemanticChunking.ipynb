# %%
from langchain_experimental.text_splitter import SemanticChunker
from langchain_openai import OpenAIEmbeddings

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
embed = OpenAIEmbeddings(
    model="text-embedding-3-small"
)

# %%
splitter = SemanticChunker(embed)

# %%
text = """
Artificial Intelligence is transforming industries across the world.
Machine Learning is a subset of AI that enables systems to learn from data.
Deep Learning is a subset of Machine Learning that uses neural networks.

The stock market fluctuates due to several economic indicators.
Investors analyze financial statements before making investments.
Portfolio diversification reduces investment risk.

Football is one of the world's most popular sports.
The FIFA World Cup is held every four years.
"""

# %%
docs = splitter.create_documents([text])

# %%
docs
# Out:
# [Document(metadata={}, page_content='\nArtificial Intelligence is transforming industries across the world. Machine Learning is a subset of AI that enables systems to learn from data. Deep Learning is a subset of Machine Learning that uses neural networks. The stock market fluctuates due to several economic indicators.'),
#  Document(metadata={}, page_content="Investors analyze financial statements before making investments. Portfolio diversification reduces investment risk. Football is one of the world's most popular sports. The FIFA World Cup is held every four years. ")]

# %%
for i, doc in enumerate(docs):
    print(f"\nChunk {i+1}")
    print(doc.page_content)
# Out:
# Chunk 1
#
# Artificial Intelligence is transforming industries across the world. Machine Learning is a subset of AI that enables systems to learn from data. Deep Learning is a subset of Machine Learning that uses neural networks. The stock market fluctuates due to several economic indicators.
#
# Chunk 2
# Investors analyze financial statements before making investments. Portfolio diversification reduces investment risk. Football is one of the world's most popular sports. The FIFA World Cup is held every four years.
